# %% [markdown]
# # Customer Lifetime Value
# ## Author: Eren ERİŞ

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ydata_profiling
from pycaret.regression import*

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 088F-1ED4
#
#  Directory of C:\Users\EREN\Documents\YapayZeka\GitHub\21Project\Customer Lifetime Value Analysis
#
# 01/01/2024  09:48 PM    <DIR>          .
# 01/01/2024  09:48 PM    <DIR>          ..
# 01/01/2024  09:48 PM    <DIR>          .ipynb_checkpoints
# 12/25/2023  10:50 PM             5,748 acquisition_data.zip
# 04/28/2023  09:52 AM            49,862 customer_acquisition_data.csv
# 01/01/2024  09:48 PM                72 Untitled.ipynb
#                3 File(s)         55,682 bytes
#                3 Dir(s)  61,115,908,096 bytes free

# %%
df = pd.read_csv("customer_acquisition_data.csv")

# %%
df.head()
# Out:
#    customer_id           channel       cost  conversion_rate  revenue
# 0            1          referral   8.320327         0.123145     4199
# 1            2  paid advertising  30.450327         0.016341     3410
# 2            3   email marketing   5.246263         0.043822     3164
# 3            4      social media   9.546326         0.167592     1520
# 4            5          referral   8.320327         0.123145     2419

# %%
fig = sns.histplot(df, x="cost")

# %%
fig = sns.histplot(df, x="revenue")

# %%
fig = sns.countplot(df , x='channel')

# %%
df.isnull().sum()
# Out:
# customer_id        0
# channel            0
# cost               0
# conversion_rate    0
# revenue            0
# dtype: int64

# %%
df = df.drop("customer_id",axis=1)

# %%
setup(data=df,target='revenue')
# Out:
# <style type="text/css">
# #T_4f776_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4f776">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f776_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4f776_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f776_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f776_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4f776_row0_col1" class="data row0 col1" >533</td>
#     </tr>
#     <tr>
#       <th id="T_4f776_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4f776_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4f776_row1_col1" class="data row1 col1" >revenue</td>
#     </tr>
#     <tr>
#       <th id="T_4f776_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4f776_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4f776_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_4f776_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4f776_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_4f776_row3_col1" class="data row3 col1" >(800, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_4f776_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4f776_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_4f776_row4_col1" class="data row4 col1" >(800, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_4f776_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4f776_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_4f776_row5_col1" class="data row5 col1" >(560, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_4f776_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4f776_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_4f776_row6_col1" class="data row6 col1" >(240, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_4f776_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4f776_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_4f776_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_4f776_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4f776_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_4f776_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_4f776_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4f776_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_4f776_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4f776_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4f776_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_4f776_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4f776_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4f776_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_4f776_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4f776_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4f776_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_4f776_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_4f776_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4f776_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_4f776_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_4f776_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4f776_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_4f776_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4f776_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4f776_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_4f776_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_4f776_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4f776_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_4f776_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4f776_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4f776_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_4f776_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4f776_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4f776_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_4f776_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4f776_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_4f776_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_4f776_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4f776_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_4f776_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_4f776_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4f776_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_4f776_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_4f776_row21_col1" class="data row21 col1" >6846</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model  =compare_models()
# Out:
# <style type="text/css">
# #T_04d00 th {
#   text-align: left;
# }
# #T_04d00_row0_col0, #T_04d00_row0_col1, #T_04d00_row0_col2, #T_04d00_row0_col3, #T_04d00_row0_col5, #T_04d00_row0_col6, #T_04d00_row1_col0, #T_04d00_row1_col5, #T_04d00_row1_col6, #T_04d00_row2_col0, #T_04d00_row2_col1, #T_04d00_row2_col2, #T_04d00_row2_col3, #T_04d00_row2_col4, #T_04d00_row2_col5, #T_04d00_row2_col6, #T_04d00_row3_col0, #T_04d00_row3_col1, #T_04d00_row3_col2, #T_04d00_row3_col3, #T_04d00_row3_col4, #T_04d00_row3_col5, #T_04d00_row3_col6, #T_04d00_row4_col0, #T_04d00_row4_col1, #T_04d00_row4_col2, #T_04d00_row4_col3, #T_04d00_row4_col4, #T_04d00_row4_col5, #T_04d00_row4_col6, #T_04d00_row5_col0, #T_04d00_row5
row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_04d00_row0_col1" class="data row0 col1" >1072.3696</td>
#       <td id="T_04d00_row0_col2" class="data row0 col2" >1547476.4948</td>
#       <td id="T_04d00_row0_col3" class="data row0 col3" >1241.8162</td>
#       <td id="T_04d00_row0_col4" class="data row0 col4" >-0.0184</td>
#       <td id="T_04d00_row0_col5" class="data row0 col5" >0.5653</td>
#       <td id="T_04d00_row0_col6" class="data row0 col6" >0.6166</td>
#       <td id="T_04d00_row0_col7" class="data row0 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_04d00_level0_row1" class="row_heading level0 row1" >dummy</th>
#       <td id="T_04d00_row1_col0" class="data row1 col0" >Dummy Regressor</td>
#       <td id="T_04d00_row1_col1" class="data row1 col1" >1072.3687</td>
#       <td id="T_04d00_row1_col2" class="data row1 col2" >1547474.0780</td>
#       <td id="T_04d00_row1_col3" class="data row1 col3" >1241.8153</td>
#       <td id="T_04d00_row1_col4" class="data row1 col4" >-0.0184</td>
#       <td id="T_04d00_row1_col5" class="data row1 col5" >0.5653</td>
#       <td id="T_04d00_row1_col6" class="data row1 col6" >0.6166</td>
#       <td id="T_04d00_row1_col7" class="data row1 col7" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_04d00_level0_row2" class="row_heading level0 row2" >omp</th>
#       <td id="T_04d00_row2_col0" class="data row2 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_04d00_row2_col1" class="data row2 col1" >1075.4039</td>
#       <td id="T_04d00_row2_col2" class="data row2 col2" >1556188.9682</td>
#       <td id="T_04d00_row2_col3" class="data row2 col3" >1245.2879</td>
#       <td id="T_04d00_row2_col4" class="data row2 col4" >-0.0240</td>
#       <td id="T_04d00_row2_col5" class="data row2 col5" >0.5664</td>
#       <td id="T_04d00_row2_col6" class="data row2 col6" >0.6181</td>
#       <td id="T_04d00_row2_col7" class="data row2 col7" >0.0170</td>
#     </tr>
#     <tr>
#       <th id="T_04d00_level0_row3" class="row_heading level0 row3" >en</th>
#       <td id="T_04d00_row3_col0" class="data row3 col0" >Elastic Net</td>
#       <td id="T_04d00_row3_col1" class="data row3 col1" >1075.6664</td>
#       <td id="T_04d00_row3_col2" class="data row3 col2" >1557098.3333</td>
#       <td id="T_04d00_row3_col3" class="data row3 col3" >1245.6479</td>
#       <td id="T_04d00_row3_col4" class="data row3 col4" >-0.0246</td>
#       <td id="T_04d00_row3_col5" class="data row3 col5" >0.5665</td>
#       <td id="T_04d00_row3_col6" class="data row3 col6" >0.6182</td>
#       <td id="T_04d00_row3_col7" class="data row3 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_04d00_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_04d00_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_04d00_row4_col1" class="data row4 col1" >1076.4537</td>
#       <td id="T_04d00_row4_col2" class="data row4 col2" >1558603.7883</td>
#       <td id="T_04d00_row4_col3" class="data row4 col3" >1246.2585</td>
#       <td id="T_04d00_row4_col4" class="data row4 col4" >-0.0256</td>
#       <td id="T_04d00_row4_col5" class="data row4 col5" >0.5666</td>
#       <td id="T_04d00_row4_col6" class="data row4 col6" >0.6184</td>
#       <td id="T_04d00_row4_col7" class="data row4 col7" >0.0610</td>
#     </tr>
#     <tr>
#       <th id="T_04d00_level0_row5" class="row_heading level0 row5" >lasso</th>
#       <td id="T_04d00_row5_col0" class="data row5 col0" >Lasso Regression</td>
#       <td id="T_04d00_row5_col1" class="data row5 col1" >1076.5956</td>
#       <td id="T_04d00_row5_col2" class="data row5 col2" >1559984.2400</td>
#       <td id="T_04d00_row5_col3" class="data row5 col3" >1246.7962</td>
#       <td id="T_04d00_row5_col4" class="data row5 col4" >-0.0265</td>
#       <td id="T_04d00_row5_col5" class="data row5 col5" >0.5668</td>
#       <td id="T_04d00_row5_col6" class="data row5 col6" >0.6185</td>
#       <td id="T_04d00_row5_col7" class="data row5 col7" >0.0170</td>
#     </tr>

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 best_model[0]
#
# TypeError: 'BayesianRidge' object is not subscriptable
