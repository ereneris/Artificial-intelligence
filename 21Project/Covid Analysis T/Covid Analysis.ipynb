# %% [markdown]
# # COVİD ANALYSIS
#
# ### Author: Eren ERİŞ

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from pycaret.regression import*

from sklearn.model_selection import train_test_split

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 088F-1ED4
#
#  Directory of C:\Users\EREN\Documents\YapayZeka\GitHub\21Project\Covid Analysis
#
# 12/24/2023  07:14 PM    <DIR>          .
# 12/24/2023  07:14 PM    <DIR>          ..
# 12/16/2023  03:41 PM    <DIR>          .ipynb_checkpoints
# 12/16/2023  03:47 PM            12,661 Covid Analysis.ipynb
# 12/16/2023  03:42 PM               608 logs.log
# 12/18/2023  08:33 AM            16,187 nlp_kmeans.py
# 11/29/2020  02:16 PM         5,806,367 raw_data.csv
# 11/29/2020  02:16 PM         4,221,784 transformed_data.csv
#                5 File(s)     10,057,607 bytes
#                3 Dir(s)  63,208,435,712 bytes free

# %%
df = pd.read_csv("transformed_data.csv")
df2 = pd.read_csv("raw_data.csv")

# %%
df.head()
# Out:
#   CODE      COUNTRY        DATE    HDI   TC   TD  STI        POP    GDPCAP
# 0  AFG  Afghanistan  2019-12-31  0.498  0.0  0.0  0.0  17.477233  7.497754
# 1  AFG  Afghanistan  2020-01-01  0.498  0.0  0.0  0.0  17.477233  7.497754
# 2  AFG  Afghanistan  2020-01-02  0.498  0.0  0.0  0.0  17.477233  7.497754
# 3  AFG  Afghanistan  2020-01-03  0.498  0.0  0.0  0.0  17.477233  7.497754
# 4  AFG  Afghanistan  2020-01-04  0.498  0.0  0.0  0.0  17.477233  7.497754

# %%
df2.head()
# Out:
#   iso_code     location        date  total_cases  total_deaths  \
# 0      AFG  Afghanistan  2019-12-31          0.0           0.0
# 1      AFG  Afghanistan  2020-01-01          0.0           0.0
# 2      AFG  Afghanistan  2020-01-02          0.0           0.0
# 3      AFG  Afghanistan  2020-01-03          0.0           0.0
# 4      AFG  Afghanistan  2020-01-04          0.0           0.0
#
#    stringency_index  population  gdp_per_capita  human_development_index  \
# 0               0.0    38928341        1803.987                    0.498
# 1               0.0    38928341        1803.987                    0.498
# 2               0.0    38928341        1803.987                    0.498
# 3               0.0    38928341        1803.987                    0.498
# 4               0.0    38928341        1803.987                    0.498
#
#   Unnamed: 9 Unnamed: 10 Unnamed: 11  Unnamed: 12  Unnamed: 13
# 0      #NUM!       #NUM!       #NUM!    17.477233  7.497754494
# 1      #NUM!       #NUM!       #NUM!    17.477233  7.497754494
# 2      #NUM!       #NUM!       #NUM!    17.477233  7.497754494
# 3      #NUM!       #NUM!       #NUM!    17.477233  7.497754494
# 4      #NUM!       #NUM!       #NUM!    17.477233  7.497754494

# %%
df["COUNTRY"].value_counts()
# Out:
# Afghanistan        294
# Indonesia          294
# Macedonia          294
# Luxembourg         294
# Lithuania          294
#                   ...
# Tajikistan         172
# Comoros            171
# Lesotho            158
# Hong Kong           51
# Solomon Islands      4
# Name: COUNTRY, Length: 210, dtype: int64

# %%
sns.countplot(df , x="location", y="total_cases")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sns.countplot(df , x="location", y="total_cases")
#
# File D:\Users\EREN\anaconda3\envs\Tester\lib\site-packages\seaborn\categorical.py:2941, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2939     y = x
#    2940 elif x is not None and y is not None:
# -> 2941     raise ValueError("Cannot pass values for both `x` and `y`")
#    2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#
# ValueError: Cannot pass values for both `x` and `y`
