# %% [markdown]
# # Next World Prediction
# ## Author : Eren ERİŞ
#
# This

# %% [markdown]
# ![](https://i0.wp.com/thecleverprogrammer.com/wp-content/uploads/2023/07/IMG_0876.jpg?resize=768%2C652&ssl=1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Read the text file
with open('/kaggle/input/sherlock-holms/sherlock-holm.es_stories_plain-text_advs.txt', 'r', encoding='utf-8') as file:
    text = file.read()

# %%
#Mesaj formatını tokonize ediyoruz
tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])
total_words = len(tokenizer.word_index) + 1

# %%
input_sequences = [tokenizer.texts_to_sequences([line])[0][:i+1] for line in text.split('\n') for i in range(1, len(tokenizer.texts_to_sequences([line])[0]))]

# %%
max_sequence_len = max([len(seq) for seq in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))

# %%
input_sequences
# Out:
# array([[   0,    0,    0, ...,    0,    1, 1561],
#        [   0,    0,    0, ...,    1, 1561,    5],
#        [   0,    0,    0, ..., 1561,    5,  129],
#        ...,
#        [   0,    0,    0, ...,    1, 8198, 8199],
#        [   0,    0,    0, ..., 8198, 8199, 3187],
#        [   0,    0,    0, ..., 8199, 3187, 3186]], dtype=int32)

# %%
X = input_sequences[:, :-1]
y = input_sequences[:, -1]

# %%
y = np.array(tf.keras.utils.to_categorical(y, num_classes=total_words))

# %%
model = Sequential()
model.add(Embedding(total_words, 100, input_length=max_sequence_len-1))
model.add(LSTM(150))
model.add(Dense(total_words, activation='softmax'))
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_1 (Embedding)     (None, 17, 100)           820000
#
#  lstm_1 (LSTM)               (None, 150)               150600
#
#  dense_3 (Dense)             (None, 8200)              1238200
#
# ...
# Total params: 2208800 (8.43 MB)
# Trainable params: 2208800 (8.43 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, y, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 3010/3010 [==============================] - 33s 10ms/step - loss: 6.2406 - accuracy: 0.0758
# Epoch 2/100
# 3010/3010 [==============================] - 20s 7ms/step - loss: 5.5002 - accuracy: 0.1247
# Epoch 3/100
# 3010/3010 [==============================] - 20s 6ms/step - loss: 5.1089 - accuracy: 0.1490
# Epoch 4/100
# 3010/3010 [==============================] - 20s 7ms/step - loss: 4.7762 - accuracy: 0.1672
# Epoch 5/100
# 3010/3010 [==============================] - 20s 7ms/step - loss: 4.4714 - accuracy: 0.1845
# Epoch 6/100
# 3010/3010 [==============================] - 20s 7ms/step - loss: 4.1817 - accuracy: 0.2048
# Epoch 7/100
# 3010/3010 [==============================] - 20s 7ms/step - loss: 3.9058 - accuracy: 0.2304
# Epoch 8/100
# 3010/3010 [==============================] - 20s 7ms/step - loss: 3.6425 - accuracy: 0.2612
# Epoch 9/100
# 3010/3010 [==============================] - 20s 7ms/step - loss: 3.3977 - accuracy: 0.2956
# Epoch 10/100
# ...

# %%
seed_text = "I will leave if they"
next_words = 3

for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
    predicted = np.argmax(model.predict(token_list), axis=-1)
    output_word = ""
    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break
    seed_text += " " + output_word

print(seed_text)
# Out:
# ...
# 1/1 [==============================] - 0s 21ms/step
# I will leave if they will set it

# %%
seed_text = "I will leave if they"
next_words = 5

for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
    predicted = np.argmax(model.predict(token_list), axis=-1)
    output_word = ""
    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break
    seed_text += " " + output_word

print(seed_text)
# Out:
# ...
# 1/1 [==============================] - 0s 20ms/step
# I will leave if they will set it very indeed

# %%
seed_text = " married"
next_words = 5

for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
    predicted = np.argmax(model.predict(token_list), axis=-1)
    output_word = ""
    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break
    seed_text += " " + output_word

print(seed_text)
# Out:
# ...
# 1/1 [==============================] - 0s 22ms/step
#  married man mr wilson have you
