# %% [markdown]
# # Mobile Price Classification Model
# ## Author: Eren ERİS

# %% [markdown]
# Bu bir Classification örneğidir. Telefon modelleri girilerek fiyat sınıflandırması yapılmaktadır

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split;
from sklearn.metrics import accuracy_score,f1_score,classification_report,confusion_matrix

from sklearn.naive_bayes import GaussianNB , BernoulliNB 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble  import RandomForestClassifier

from pycaret.regression import*

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 088F-1ED4
#
#  Directory of C:\Users\EREN\Documents\YapayZeka\GitHub\21Project\Mobile Price Classification
#
# 01/02/2024  10:24 PM    <DIR>          .
# 01/02/2024  10:24 PM    <DIR>          ..
# 01/02/2024  10:24 PM    <DIR>          .ipynb_checkpoints
# 01/02/2024  10:24 PM                72 Mobile Price Classification.ipynb
# 12/25/2023  10:55 PM           122,403 mobile_prices.csv
#                2 File(s)        122,475 bytes
#                3 Dir(s)  62,336,344,064 bytes free

# %%
df = pd.read_csv("mobile_prices.csv")

# %%
df.head() #İlk 5 satırı getir
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB

# %%
df.isnull().sum() #Boş verileri listele
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# min       0.000000     2.000000     0.100000    80.000000     1.000000  ...
# 25%       0.000000    16.000000     0.200000   109.000000     3.000000  ...
# 50%       1.000000    32.000000     0.500000   141.000000     4.000000  ...
# 75%       1.000000    48.000000     0.800000   170.000000     7.000000  ...
# max       1.000000    64.000000     1.000000   200.000000     8.000000  ...
#
#          px_height     px_width          ram         sc_h         sc_w  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean    645.108000  1251.515500  2124.213000    12.306500     5.767000
# std     443.780811   432.199447  1084.732044     4.213245     4.356398
# min       0.000000   500.000000   256.000000     5.000000     0.000000
# 25%     282.750000   874.750000  1207.500000     9.000000     2.000000
# 50%     564.000000  1247.000000  2146.500000    12.000000     5.000000
# 75%     947.250000  1633.000000  3064.500000    16.000000     9.000000
# max    1960.000000  1998.000000  3998.000000    19.000000    18.000000
#
#          talk_time      three_g  touch_screen         wifi  price_range
# count  2000.000000  2000.000000   2000.000000  2000.000000  2000.000000
# mean     11.011000     0.761500      0.503000     0.507000     1.500000
# std       5.463955     0.426273      0.500116     0.500076     1.118314
# min       2.000000     0.000000      0.000000     0.000000     0.000000
# 25%       6.000000     1.000000      0.000000     0.000000     0.750000
# 50%      11.000000     1.000000      1.000000     1.000000     1.500000
# 75%      16.000000     1.000000      1.000000     1.000000     2.250000
# max      20.000000     1.000000      1.000000     1.000000     3.000000
#
# [8 rows x 21 columns]

# %%
df.corr(numeric_only=True)
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# px_width           -0.008402 -0.041533    -0.009476  0.014291 -0.005176
# ram                -0.000653  0.026351     0.003443  0.041072  0.015099
# sc_h               -0.029959 -0.002952    -0.029078 -0.011949 -0.011014
# sc_w               -0.021421  0.000613    -0.007378 -0.016666 -0.012373
# talk_time           0.052510  0.013934    -0.011432 -0.039404 -0.006829
# three_g             0.011522 -0.030236    -0.046433 -0.014008  0.001793
# touch_screen       -0.010516  0.010061     0.019756 -0.017117 -0.014828
# wifi               -0.008343 -0.021863    -0.024471  0.022740  0.020085
# price_range         0.200723  0.020573    -0.006606  0.017444  0.021998
#
#                  four_g  int_memory     m_dep  mobile_wt   n_cores  ...  \
# battery_power  0.015665   -0.004004  0.034085   0.001844 -0.029727  ...
# blue           0.013443    0.041177  0.004049  -0.008605  0.036161  ...
# clock_speed   -0.043073    0.006545 -0.014364   0.012350 -0.005724  ...
# dual_sim       0.003187   -0.015679 -0.022142  -0.008979 -0.024658  ...
# fc            -0.016560   -0.029133 -0.001791   0.023618 -0.013356  ...
# four_g         1.000000    0.008690 -0.001823  -0.016537 -0.029706  ...
# int_memory     0.008690    1.000000  0.006886  -0.034214 -0.028310  ...
# m_dep         -0.001823    0.006886  1.000000   0.021756 -0.003504  ...
# mobile_wt     -0.016537   -0.034214  0.021756   1.000000 -0.018989  ...
# n_cores       -0.029706   -0.028310 -0.003504  -0.018989  1.000000  ...
# pc            -0.005598   -0.033273  0.026282   0.018844 -0.001193  ...
# px_height     -0.019236    0.010441  0.025263   0.000939 -0.006872  ...
# px_width       0.007448   -0.008335  0.023566   0.000090  0.024480  ...
# ram            0.007313    0.032813 -0.009434  -0.002581  0.004868  ...
# sc_h           0.027166    0.037771 -0.025348  -0.033855 -0.000315  ...
# sc_w           0.037005    0.011731 -0.018388  -0.020761  0.025826  ...
# talk_time     -0.046628   -0.002790  0.017003   0.006209  0.013148  ...
# three_g        0.584246   -0.009366 -0.012065   0.001551 -0.014733  ...
# touch_screen   0.016758   -0.026999 -0.002638  -0.014368  0.023774  ...
# wifi          -0.017620    0.006993 -0.028353  -0.000409 -0.009964  ...
# price_range    0.014772    0.044435  0.000853  -0.030302  0.004399  ...
#
#                px_height  px_width       ram      sc_h      sc_w  talk_time  \
# battery_power   0.014901 -0.008402 -0.000653 -0.029959 -0.021421   0.052510
# blue           -0.006872 -0.041533  0.026351 -0.002952  0.000613   0.013934
# clock_speed    -0.014523 -0.009476  0.003443 -0.029078 -0.007378  -0.011432
# dual_sim       -0.020875  0.014291  0.041072 -0.011949 -0.016666  -0.039404
# fc             -0.009990 -0.005176  0.015099 -0.011014 -0.012373  -0.006829
# four_g         -0.019236  0.007448  0.007313  0.027166  0.037005  -0.046628
# int_memory      0.010441 -0.008335  0.032813  0.037771  0.011731  -0.002790
# m_dep           0.025263  0.023566 -0.009434 -0.025348 -0.018388   0.017003
# mobile_wt       0.000939  0.000090 -0.002581 -0.033855 -0.020761   0.006209
# n_cores        -0.006872  0.024480  0.004868 -0.000315  0.025826   0.013148
# pc             -0.018465  0.004196  0.028984  0.004938 -0.023819   0.014657
# px_height       1.000000  0.510664 -0.020352  0.059615  0.043038  -0.010645
# px_width        0.510664  1.000000  0.004105  0.021599  0.034699   0.006720
# ram            -0.020352  0.004105  1.000000  0.015996  0.035576   0.010820
# sc_h            0.059615  0.021599  0.015996  1.000000  0.506144  -0.017335
# sc_w            0.043038  0.034699  0.035576  0.506144  1.000000  -0.022821
# talk_time      -0.010645  0.006720  0.010820 -0.017335 -0.022821   1.000000
# three_g        -0.031174  0.000350  0.015795  0.012033  0.030941  -0.042688
# touch_screen    0.021891 -0.001628 -0.030455 -0.020023  0.012720   0.017196
# wifi            0.051824  0.030319  0.022669  0.025929  0.035423  -0.029504
# price_range     0.148858  0.165818  0.917046  0.022986  0.038711   0.021859
#
#                 three_g  touch_screen      wifi  price_range
# battery_power  0.011522     -0.010516 -0.008343     0.200723
# blue          -0.030236      0.010061 -0.021863     0.020573
# clock_speed   -0.046433      0.019756 -0.024471    -0.006606
# dual_sim      -0.014008     -0.017117  0.022740     0.017444
# fc             0.001793     -0.014828  0.020085     0.021998
# four_g         0.584246      0.016758 -0.017620     0.014772
# int_memory    -0.009366     -0.026999  0.006993     0.044435
# m_dep         -0.012065     -0.002638 -0.028353     0.000853
# mobile_wt      0.001551     -0.014368 -0.000409    -0.030302
# n_cores       -0.014733      0.023774 -0.009964     0.004399
# pc            -0.001322     -0.008742  0.005389     0.033599
# px_height     -0.031174      0.021891  0.051824     0.148858
# px_width       0.000350     -0.001628  0.030319     0.165818
# ram            0.015795     -0.030455  0.022669     0.917046
# sc_h           0.012033     -0.020023  0.025929     0.022986
# sc_w           0.030941      0.012720  0.035423     0.038711
# talk_time     -0.042688      0.017196 -0.029504     0.021859
# three_g        1.000000      0.013917  0.004316     0.023611
# touch_screen   0.013917      1.000000  0.011917    -0.030411
# wifi           0.004316      0.011917  1.000000     0.018785
# price_range    0.023611     -0.030411  0.018785     1.000000
#
# [21 rows x 21 columns]

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", linecolor='white', linewidths=1)
# Out:
# <AxesSubplot: >

# %%
def getModel(model , x_train , y_train , x_test , y_test):
    mod = model.fit(x_train , y_train)
    predict = model.predict(x_test)
    print("------------Accury Score------------")
    print(accuracy_score(predict,y_test))
    print("------------Classification Report------------")
    print(classification_report(predict,y_test))
    sns.heatmap(confusion_matrix(predict,y_test),annot=True,fmt='.2f',cmap="crest")

# %%
x = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
getModel(GaussianNB() , x_train , y_train , x_test , y_test)
# Out:
# ------------Accury Score------------
# 0.7975
# ------------Classification Report------------
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90       105
#            1       0.68      0.77      0.72        81
#            2       0.77      0.64      0.70       111
#            3       0.81      0.88      0.85       103
#
#     accuracy                           0.80       400
#    macro avg       0.79      0.80      0.79       400
# weighted avg       0.80      0.80      0.80       400

# %%
getModel(BernoulliNB(), x_train , y_train , x_test , y_test)
# Out:
# ------------Accury Score------------
# 0.255
# ------------Classification Report------------
#               precision    recall  f1-score   support
#
#            0       0.20      0.24      0.22        88
#            1       0.19      0.20      0.19        85
#            2       0.34      0.27      0.30       115
#            3       0.29      0.29      0.29       112
#
#     accuracy                           0.26       400
#    macro avg       0.25      0.25      0.25       400
# weighted avg       0.26      0.26      0.26       400

# %%
getModel(KNeighborsClassifier(), x_train , y_train , x_test , y_test)
# Out:
# ------------Accury Score------------
# 0.9425
# ------------Classification Report------------
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       106
#            1       0.93      0.92      0.93        92
#            2       0.91      0.89      0.90        94
#            3       0.94      0.97      0.95       108
#
#     accuracy                           0.94       400
#    macro avg       0.94      0.94      0.94       400
# weighted avg       0.94      0.94      0.94       400

# %%
getModel( LogisticRegression(), x_train , y_train , x_test , y_test)
# Out:
# D:\Users\EREN\anaconda3\envs\Tester\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ------------Accury Score------------
# 0.6325
# ------------Classification Report------------
#               precision    recall  f1-score   support
#
#            0       0.75      0.82      0.79        96
#            1       0.51      0.52      0.51        89
#            2       0.50      0.48      0.49        96
#            3       0.73      0.69      0.71       119
#
#     accuracy                           0.63       400
#    macro avg       0.62      0.63      0.62       400
# weighted avg       0.63      0.63      0.63       400

# %%
getModel( DecisionTreeClassifier(), x_train , y_train , x_test , y_test)
# Out:
# ------------Accury Score------------
# 0.8225
# ------------Classification Report------------
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89       101
#            1       0.81      0.75      0.78        99
#            2       0.70      0.75      0.72        85
#            3       0.88      0.86      0.87       115
#
#     accuracy                           0.82       400
#    macro avg       0.82      0.82      0.82       400
# weighted avg       0.82      0.82      0.82       400

# %%
getModel( RandomForestClassifier(), x_train , y_train , x_test , y_test)
# Out:
# ------------Accury Score------------
# 0.9
# ------------Classification Report------------
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94       107
#            1       0.88      0.88      0.88        91
#            2       0.87      0.83      0.85        96
#            3       0.89      0.94      0.92       106
#
#     accuracy                           0.90       400
#    macro avg       0.90      0.90      0.90       400
# weighted avg       0.90      0.90      0.90       400

# %%
y
# Out:
# array([1, 2, 2, ..., 3, 0, 3], dtype=int64)

# %%
#Auto ML Karşılaştırma
setup(data=df,target='price_range')
# Out:
# <style type="text/css">
# #T_55b81_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_55b81">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55b81_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_55b81_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55b81_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_55b81_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_55b81_row0_col1" class="data row0 col1" >3345</td>
#     </tr>
#     <tr>
#       <th id="T_55b81_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_55b81_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_55b81_row1_col1" class="data row1 col1" >price_range</td>
#     </tr>
#     <tr>
#       <th id="T_55b81_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_55b81_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_55b81_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_55b81_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_55b81_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_55b81_row3_col1" class="data row3 col1" >(2000, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_55b81_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_55b81_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_55b81_row4_col1" class="data row4 col1" >(2000, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_55b81_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_55b81_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_55b81_row5_col1" class="data row5 col1" >(1400, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_55b81_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_55b81_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_55b81_row6_col1" class="data row6 col1" >(600, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_55b81_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_55b81_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_55b81_row7_col1" class="data row7 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_55b81_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_55b81_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_55b81_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_55b81_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_55b81_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_55b81_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_55b81_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_55b81_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_55b81_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_55b81_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_55b81_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_55b81_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_55b81_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_55b81_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_55b81_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_55b81_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_55b81_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_55b81_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_55b81_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_55b81_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_55b81_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_55b81_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_55b81_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_55b81_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_55b81_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_55b81_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_55b81_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_55b81_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_55b81_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_55b81_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_55b81_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_55b81_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_55b81_row18_col1" class="data row18 col1" >9563</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model  =compare_models()
# Out:
# <style type="text/css">
# #T_a0f24 th {
#   text-align: left;
# }
# #T_a0f24_row0_col0, #T_a0f24_row1_col0, #T_a0f24_row1_col1, #T_a0f24_row1_col2, #T_a0f24_row1_col3, #T_a0f24_row1_col4, #T_a0f24_row1_col5, #T_a0f24_row1_col6, #T_a0f24_row2_col0, #T_a0f24_row2_col1, #T_a0f24_row2_col2, #T_a0f24_row2_col3, #T_a0f24_row2_col4, #T_a0f24_row2_col5, #T_a0f24_row2_col6, #T_a0f24_row3_col0, #T_a0f24_row3_col1, #T_a0f24_row3_col2, #T_a0f24_row3_col3, #T_a0f24_row3_col4, #T_a0f24_row3_col5, #T_a0f24_row3_col6, #T_a0f24_row4_col0, #T_a0f24_row4_col1, #T_a0f24_row4_col2, #T_a0f24_row4_col3, #T_a0f24_row4_col4, #T_a0f24_row4_col5, #T_a0f24_row4_col6, #T_a0f24_row5_col0, #T_a0f24_row5_col1, #T_a0f24_row5_col2, #T_a0f24_row5_col3, #T_a0f24_row5_col4, #T_a0f24_row5_col5, #T_a0f24_row5_col6, #T_a0f24_row6_col0, #T_a0f24_row6_col1, #T_a0f24_row6_col2, #T_a0f24_row6_col3, #T_a0f24_row6_col4, #T_a0f24_row6_col5, #T_a0f24_row6_col6, #T_a0f24_row7_col0, #T_a0f24_row7_col1, #T_a0f24_row7_col2, #T_a0f24_row7_col3, #T_a0f24_row7_col4, #T_a0f24_row7_col5, #T_a0f24_row7_col6, #T_a0f24_row8_col0, #T_a0f24_row8_col1, #T_a0f24_row8_col2, #T_a0f24_row8_col3, #T_a0f24_row8_col4, #T_a0f24_row8_col5, #T_a0f24_row8_col6, #T_a0f24_row9_col0, #T_a0f24_row9_col1, #T_a0f24_row9_col2, #T_a0f24_row9_col3, #T_a0f24_row9_col4, #T_a0f24_row9_col5, #T_a0f24_row9_col6, #T_a0f24_row10_col0, #T_a0f24_row10_col1, #T_a0f24_row10_col2, #T_a0f24_row10_col3, #T_a0f24_row10_col4, #T_a0f24_row10_col5, #T_a0f24_row10_col6, #T_a0f24_row11_col0, #T_a0f24_row11_col1, #T_a0f24_row11_col2, #T_a0f24_row11_col3, #T_a0f24_row11_col4, #T_a0f24_row11_col5, #T_a0f24_row11_col6, #T_a0f24_row12_col0, #T_a0f24_row12_col1, #T_a0f24_row12_col2, #T_a0f24_row12_col3, #T_a0f24_row12_col4, #T_a0f24_row12_col5, #T_a0f24_row12_col6, #T_a0f24_row13_col0, #T_a0f24_row13_col1, #T_a0f24_row13_col2, #T_a0f24_row13_col3, #T_a0f24_row13_col4, #T_a0f24_row13_col5, #T_a0f24_row13_col6, #T_a0f24_row14_col0, #T_a0f24_row14_col1, #T_a0f24_row14_col2, #T_a0f24_row14_col3, #T_a0f24_row14_col4, #T_a0f24_row14_col5, #T_a0f24_row14_col6, #T_a0f24_row15_col0, #T_a0f24_row15_col1, #T_a0f24_row15_col2, #T_a0f24_row15_col3, #T_a0f24_row15_col4, #T_a0f24_row15_col5, #T_a0f24_row15_col6, #T_a0f24_row16_col0, #T_a0f24_row16_col1, #T_a0f24_row16_col2, #T_a0f24_row16_col3, #T_a0f24_row16_col4, #T_a0f24_row16_col5, #T_a0f24_row16_col6, #T_a0f24_row17_col0, #T_a0f24_row17_col1, #T_a0f24_row17_col2, #T_a0f24_row17_col3, #T_a0f24_row17_col4, #T_a0f24_row17_col5, #T_a0f24_row17_col6 {
#   text-align: left;
# }
# #T_a0f24_row0_col1, #T_a0f24_row0_col2, #T_a0f24_row0_col3, #T_a0f24_row0_col4, #T_a0f24_row0_col5, #T_a0f24_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_a0f24_row0_col7, #T_a0f24_row1_col7, #T_a0f24_row2_col7, #T_a0f24_row3_col7, #T_a0f24_row4_col7, #T_a0f24_row5_col7, #T_a0f24_row7_col7, #T_a0f24_row8_col7, #T_a0f24_row9_col7, #T_a0f24_row10_col7, #T_a0f24_row11_col7, #T_a0f24_row12_col7, #T_a0f24_row13_col7, #T_a0f24_row14_col7, #T_a0f24_row15_col7, #T_a0f24_row16_col7, #T_a0f24_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_a0f24_row6_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_a0f24">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0f24_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a0f24_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a0f24_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a0f24_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a0f24_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a0f24_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a0f24_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_a0f24_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0f24_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_a0f24_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_a0f24_row0_col1" class="data row0 col1" >0.1317</td>
#       <td id="T_a0f24_row0_col2" class="data row0 col2" >0.0644</td>
#       <td id="T_a0f24_row0_col3" class="data row0 col3" >0.2521</td>
#       <td id="T_a0f24_row0_col4" class="data row0 col4" >0.9474</td>
#       <td id="T_a0f24_row0_col5" class="data row0 col5" >0.1205</td>
#       <td id="T_a0f24_row0_col6" class="data row0 col6" >0.0981</td>
#       <td id="T_a0f24_row0_col7" class="data row0 col7" >0.0230</td>
#     </tr>
#     <tr>
#       <th id="T_a0f24_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_a0f24_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_a0f24_row1_col1" class="data row1 col1" >0.1769</td>
#       <td id="T_a0f24_row1_col2" class="data row1 col2" >0.0685</td>
#       <td id="T_a0f24_row1_col3" class="data row1 col3" >0.2610</td>
#       <td id="T_a0f24_row1_col4" class="data row1 col4" >0.9440</td>
#       <td id="T_a0f24_row1_col5" class="data row1 col5" >0.1265</td>
#       <td id="T_a0f24_row1_col6" class="data row1 col6" >0.1266</td>
#       <td id="T_a0f24_row1_col7" class="data row1 col7" >0.0820</td>
#     </tr>
#     <tr>
#       <th id="T_a0f24_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_a0f24_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_a0f24_row2_col1" class="data row2 col1" >0.2037</td>
#       <td id="T_a0f24_row2_col2" class="data row2 col2" >0.0794</td>
#       <td id="T_a0f24_row2_col3" class="data row2 col3" >0.2815</td>
#       <td id="T_a0f24_row2_col4" class="data row2 col4" >0.9351</td>
#       <td id="T_a0f24_row2_col5" class="data row2 col5" >0.1368</td>
#       <td id="T_a0f24_row2_col6" class="data row2 col6" >0.1497</td>
#       <td id="T_a0f24_row2_col7" class="data row2 col7" >0.0890</td>
#     </tr>
#     <tr>
#       <th id="T_a0f24_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_a0f24_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_a0f24_row3_col1" class="data row3 col1" >0.1793</td>
#       <td id="T_a0f24_row3_col2" class="data row3 col2" >0.0799</td>
#       <td id="T_a0f24_row3_col3" class="data row3 col3" >0.2823</td>
#       <td id="T_a0f24_row3_col4" class="data row3 col4" >0.9346</td>
#       <td id="T_a0f24_row3_col5" class="data row3 col5" >0.1380</td>
#       <td id="T_a0f24_row3_col6" class="data row3 col6" >0.1307</td>
#       <td id="T_a0f24_row3_col7" class="data row3 col7" >0.1610</td>
#     </tr>
#     <tr>
#       <th id="T_a0f24_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_a0f24_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_a0f24_row4_col1" class="data row4 col1" >0.2265</td>
#       <td id="T_a0f24_row4_col2" class="data row4 col2" >0.0813</td>
#       <td id="T_a0f24_row4_col3" class="data row4 col3" >0.2847</td>
#       <td id="T_a0f24_row4_col4" class="data row4 col4" >0.9337</td>
#       <td id="T_a0f24_row4_col5" class="data row4 col5" >0.1422</td>
#       <td id="T_a0f24_row4_col6" class="data row4 col6" >0.1554</td>
#       <td id="T_a0f24_row4_col7" class="data row4 col7" >0.1230</td>
#     </tr>
#     <tr>
#       <th id="T_a0f24_level0_row5" class="row_heading level0 row5" >br</th>
#       <td id="T_a0f24_row5_col0" class="data row5 col0" >Bayesian Ridge</td>
#       <td id="T_a0f24_row5_col1" class="data row5 col1" >0.2695</td>
#       <td id="T_a0f24_row5_col2" class="data row5 col2" >0.1038</td>
#       <td id="T_a0f24_row5_col3" class="data row5 col3" >0.3220</td>
#       <td id="T_a0f24_row5_col4" class="data row5 col4" >0.9152</td>
#       <td id="T_a0f24_row5_col5" class="data row5 col5" >0.1679</td>
#       <td id="T_a0f24_row5_col6" class="data row5 col6" >0.1530</td>
#       <td id="T_a0f24_row5_col7" class="data row5 col7" >0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_a0f24_level0_row6" c
